# %%
from zero import ZeroClient
import client_data
import client_ml
import client_plot
from prefect import task, Flow, Parameter
from prefect.tasks.prefect import create_flow_run, wait_for_flow_run

# %%
client1 = ZeroClient("localhost", 5559)
client2 = ZeroClient("localhost", 5558)
client3 = ZeroClient("localhost", 5557)
clients = [client1, client2, client3]

# %%
dfs = []
for i in range(len(clients)):
    data_id =  "covid_" + str(i) + ".csv"
    df = client_data.client_csv_to_df(clients[i], data_id)
    dfs.append(df)
# Out:
# <contextlib._GeneratorContextManager object at 0x7f8b084dfca0>
# <contextlib._GeneratorContextManager object at 0x7f8b084dfb20>
# <contextlib._GeneratorContextManager object at 0x7f8a6c485fd0>

# %%
dfs
# Out:
# [{'id': 'dc19ac230bb44991b32044f76616ee92',
#   'type': "<class 'pandas.core.frame.DataFrame'>",
#   '_SecretClientObject': True},
#  {'id': 'dc26cbf924884668be574726edac470a',
#   'type': "<class 'pandas.core.frame.DataFrame'>",
#   '_SecretClientObject': True},
#  {'id': '6657ba15ad954b76b63346662cb0040d',
#   'type': "<class 'pandas.core.frame.DataFrame'>",
#   '_SecretClientObject': True}]

# %%
for i in range(len(clients)):
    client_plot.client_plot_miss(clients[i], dfs[i])

# %%
for i in range(len(clients)):
    client_plot.client_plot_countplot(clients[i], "COVID-19", dfs[i])

# %%
col_labels = []
for i in range(len(clients)):
    col_label = client_data.client_df_get_col_names(clients[i], dfs[i])
    col_types = client_data.client_df_get_unique(clients[i], dfs[i])
    print(col_types)
    col_labels.append(list(col_label))
# Out:
# {'Breathing Problem': ['Yes', 'No'], 'Fever': ['Yes', 'No'], 'Dry Cough': ['Yes', 'No'], 'Sore throat': ['Yes', 'No'], 'Running Nose': ['Yes', 'No'], 'Asthma': ['No', 'Yes'], 'Chronic Lung Disease': ['No', 'Yes'], 'Headache': ['No', 'Yes'], 'Heart Disease': ['No', 'Yes'], 'Diabetes': ['Yes', 'No'], 'Hyper Tension': ['Yes', 'No'], 'Fatigue ': ['Yes', 'No'], 'Gastrointestinal ': ['Yes', 'No'], 'Abroad travel': ['No', 'Yes'], 'Contact with COVID Patient': ['Yes', 'No'], 'Attended Large Gathering': ['No', 'Yes'], 'Visited Public Exposed Places': ['Yes', 'No'], 'Family working in Public Exposed Places': ['Yes', 'No'], 'Wearing Masks': ['No'], 'Sanitization from Market': ['No'], 'COVID-19': ['Yes', 'No']}
# {'Breathing Problem': ['Yes', 'No'], 'Fever': ['Yes', 'No'], 'Dry Cough': ['Yes', 'No'], 'Sore throat': ['Yes', 'No'], 'Running Nose': ['No', 'Yes'], 'Asthma': ['No', 'Yes'], 'Chronic Lung Disease': ['No', 'Yes'], 'Headache': ['No', 'Yes'], 'Heart Disease': ['No', 'Yes'], 'Diabetes': ['Yes', 'No'], 'Hyper Tension': ['Yes', 'No'], 'Fatigue ': ['Yes', 'No'], 'Gastrointestinal ': ['Yes', 'No'], 'Abroad travel': ['Yes', 'No'], 'Contact with COVID Patient': ['No', 'Yes'], 'Attended Large Gathering': ['Yes', 'No'], 'Visited Public Exposed Places': ['No', 'Yes'], 'Family working in Public Exposed Places': ['Yes', 'No'], 'Wearing Masks': ['No'], 'Sanitization from Market': ['No'], 'COVID-19': ['Yes', 'No']}
# {'Breathing Problem': ['Yes', 'No'], 'Fever': ['Yes', 'No'], 'Dry Cough': ['No', 'Yes'], 'Sore throat': ['Yes', 'No'], 'Running Nose': ['No', 'Yes'], 'Asthma': ['Yes', 'No'], 'Chronic Lung Disease': ['No', 'Yes'], 'Headache': ['No', 'Yes'], 'Heart Disease': ['Yes', 'No'], 'Diabetes': ['Yes', 'No'], 'Hyper Tension': ['Yes', 'No'], 'Fatigue ': ['Yes', 'No'], 'Gastrointestinal ': ['No', 'Yes'], 'Abroad travel': ['No', 'Yes'], 'Contact with COVID Patient': ['No', 'Yes'], 'Attended Large Gathering': ['No', 'Yes'], 'Visited Public Exposed Places': ['Yes', 'No'], 'Family working in Public Exposed Places': ['No', 'Yes'], 'Wearing Masks': ['No'], 'Sanitization from Market': ['No'], 'COVID-19': ['Yes', 'No']}

# %%
for i in range(len(clients)):
    dfs[i] = client_data.client_fit_transform(clients[i], dfs[i], col_labels[0])

# %%
for i in range(len(clients)):
    client_plot.client_plot_hist(clients[i], dfs[i])

# %%
for i in range(len(clients)):
    client_plot.client_plot_corr(clients[i], dfs[i])

# %%
cleaned_dfs = []
dropped_labels = ['Running Nose', 
                  'Chronic Lung Disease', 
                  'Headache', 
                  'Heart Disease', 
                  'Diabetes', 
                  'Gastrointestinal ', 
                  'Wearing Masks', 
                  'Sanitization from Market', 
                  'Asthma', 
                  'Fatigue ']
for i in range(len(clients)):
    cleaned_df = client_data.client_df_drop(clients[i], dfs[i], dropped_labels)
    cleaned_dfs.append(cleaned_df)

# %%
X = []
y = []
for i in range(len(clients)):
    X.append(client_data.client_df_drop(clients[i], cleaned_dfs[i], 'COVID-19'))
    y.append(client_data.client_df_get_col(clients[i], cleaned_dfs[i], 'COVID-19'))

# %%
m = client_ml.FederatedLogisticRegression(clients)

# %%
m.data_setup(X, y, 0.2)
m.model_setup(lr=0.5)

# %%
m.fit(100)
m.report()
# Out:
# /home/jjj/playground/client_ml.py:136: RuntimeWarning: invalid value encountered in true_divide
#   tprs.append(float(true_positive) / (true_positive + false_negative))
# [0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, 0.19834710743801653, nan]
# [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, 0.19834710743801653]
# /home/jjj/playground/client_ml.py:137: RuntimeWarning: invalid value encountered in true_divide
#   fprs.append(float(false_positive) / (false_positive + true_negative))

# %%
task_csv_to_df = task(client_data.client_csv_to_df)
task_fit_transform = task(client_data.client_fit_transform)
task_df_drop = task(client_data.client_df_drop)
task_df_get_col = task(client_data.client_df_get_col)
task_df_get_col_names = task(client_data.client_df_get_col_names)

@task
def get_result(x):
    return x

dropped_labels = ['Running Nose',
                  'Chronic Lung Disease', 
                  'Headache', 
                  'Heart Disease', 
                  'Diabetes', 
                  'Gastrointestinal ', 
                  'Wearing Masks', 
                  'Sanitization from Market', 
                  'Asthma', 
                  'Fatigue ']

# %%
with Flow("preprocess") as f_preprocess:
    parameter_dropped_labels = Parameter("X", default = dropped_labels)
    parameter_y_label = Parameter("y_label", default = 'COVID-19')
    
    X = []
    y = []
    for i in range(len(clients)):
        data_id =  "covid_" + str(i) + ".csv"
        df = task_csv_to_df(clients[i], data_id)
        col_label = task_df_get_col_names(clients[i], df)
        df = task_fit_transform(clients[i], df, col_label)
        cleaned_df = task_df_drop(clients[i], df, parameter_dropped_labels)
        X.append(task_df_drop(clients[i], cleaned_df, parameter_y_label))
        y.append(task_df_get_col(clients[i], cleaned_df, parameter_y_label))
    resX = get_result(X)
    resy = get_result(y)

# %%
f_preprocess.visualize()

# %%
state = f_preprocess.run()
# Out:
# [2022-06-30 11:06:38-0400] INFO - prefect.FlowRunner | Beginning Flow run for 'preprocess'
# 30-Jun-22 11:06:38  INFO  115128  flow_runner > Beginning Flow run for 'preprocess'
# [2022-06-30 11:06:38-0400] INFO - prefect.TaskRunner | Task 'client_csv_to_df': Starting task run...
# 30-Jun-22 11:06:38  INFO  115128  task_runner > Task 'client_csv_to_df': Starting task run...
# [2022-06-30 11:06:38-0400] INFO - prefect.TaskRunner | Task 'client_csv_to_df': Finished task run for task with final state: 'Success'
# 30-Jun-22 11:06:38  INFO  115128  task_runner > Task 'client_csv_to_df': Finished task run for task with final state: 'Success'
# [2022-06-30 11:06:38-0400] INFO - prefect.TaskRunner | Task 'client_csv_to_df': Starting task run...
# 30-Jun-22 11:06:38  INFO  115128  task_runner > Task 'client_csv_to_df': Starting task run...
# [2022-06-30 11:06:38-0400] INFO - prefect.TaskRunner | Task 'client_csv_to_df': Finished task run for task with final state: 'Success'
# 30-Jun-22 11:06:38  INFO  115128  task_runner > Task 'client_csv_to_df': Finished task run for task with final state: 'Success'
# [2022-06-30 11:06:38-0400] INFO - prefect.TaskRunner | Task 'client_df_get_col_names': Starting task run...
# 30-Jun-22 11:06:38  INFO  115128  task_runner > Task 'client_df_get_col_names': Starting task run...
# [2022-06-30 11:06:38-0400] INFO - prefect.TaskRunner | Task 'client_df_get_col_names': Finished task run for task with final state: 'Success'
# 30-Jun-22 11:06:38  INFO  115128  task_runner > Task 'client_df_get_col_names': Finished task run for task with final state: 'Success'
# [2022-06-30 11:06:38-0400] INFO - prefect.TaskRunner | Task 'client_fit_transform': Starting task run...
# 30-Jun-22 11:06:38  INFO  115128  task_runner > Task 'client_fit_transform': Starting task run...
# [2022-06-30 11:06:38-0400] INFO - prefect.TaskRunner | Task 'client_fit_transform': Finished task run for task with final state: 'Success'
# 30-Jun-22 11:06:38  INFO  115128  task_runner > Task 'client_fit_transform': Finished task run for task with final state: 'Success'
# [2022-06-30 11:06:38-0400] INFO - prefect.TaskRunner | Task 'X': Starting task run...
# 30-Jun-22 11:06:38  INFO  115128  task_runner > Task 'X': Starting task run...
# [2022-06-30 11:06:38-0400] INFO - prefect.TaskRunner | Task 'X': Finished task run for task with final state: 'Success'
# 30-Jun-22 11:06:38  INFO  115128  task_runner > Task 'X': Finished task run for task with final state: 'Success'
# [2022-06-30 11:06:38-0400] INFO - prefect.TaskRunner | Task 'y_label': Starting task run...
# 30-Jun-22 11:06:38  INFO  115128  task_runner > Task 'y_label': Starting task run...
# [2022-06-30 11:06:38-0400] INFO - prefect.TaskRunner | Task 'y_label': Finished task run for task with final state: 'Success'
# 30-Jun-22 11:06:38  INFO  115128  task_runner > Task 'y_label': Finished task run for task with final state: 'Success'
# [2022-06-30 11:06:38-0400] INFO - prefect.TaskRunner | Task 'client_csv_to_df': Starting task run...
# 30-Jun-22 11:06:38  INFO  115128  task_runner > Task 'client_csv_to_df': Starting task run...
# [2022-06-30 11:06:38-0400] INFO - prefect.TaskRunner | Task 'client_csv_to_df': Finished task run for task with final state: 'Success'
# 30-Jun-22 11:06:38  INFO  115128  task_runner > Task 'client_csv_to_df': Finished task run for task with final state: 'Success'
# [2022-06-30 11:06:38-0400] INFO - prefect.TaskRunner | Task 'client_df_get_col_names': Starting task run...
# 30-Jun-22 11:06:38  INFO  115128  task_runner > Task 'client_df_get_col_names': Starting task run...
# [2022-06-30 11:06:38-0400] INFO - prefect.TaskRunner | Task 'client_df_get_col_names': Finished task run for task with final state: 'Success'
# 30-Jun-22 11:06:38  INFO  115128  task_runner > Task 'client_df_get_col_names': Finished task run for task with final state: 'Success'
# [2022-06-30 11:06:38-0400] INFO - prefect.TaskRunner | Task 'client_df_drop': Starting task run...
# 30-Jun-22 11:06:38  INFO  115128  task_runner > Task 'client_df_drop': Starting task run...
# [2022-06-30 11:06:38-0400] INFO - prefect.TaskRunner | Task 'client_df_drop': Finished task run for task with final state: 'Success'
# 30-Jun-22 11:06:38  INFO  115128  task_runner > Task 'client_df_drop': Finished task run for task with final state: 'Success'
# [2022-06-30 11:06:38-0400] INFO - prefect.TaskRunner | Task 'client_df_get_col_names': Starting task run...
# 30-Jun-22 11:06:38  INFO  115128  task_runner > Task 'client_df_get_col_names': Starting task run...
# [2022-06-30 11:06:38-0400] INFO - prefect.TaskRunner | Task 'client_df_get_col_names': Finished task run for task with final state: 'Success'
# 30-Jun-22 11:06:38  INFO  115128  task_runner > Task 'client_df_get_col_names': Finished task run for task with final state: 'Success'
# [2022-06-30 11:06:38-0400] INFO - prefect.TaskRunner | Task 'client_fit_transform': Starting task run...
# 30-Jun-22 11:06:38  INFO  115128  task_runner > Task 'client_fit_transform': Starting task run...
# [2022-06-30 11:06:38-0400] INFO - prefect.TaskRunner | Task 'client_fit_transform': Finished task run for task with final state: 'Success'
# 30-Jun-22 11:06:38  INFO  115128  task_runner > Task 'client_fit_transform': Finished task run for task with final state: 'Success'
# [2022-06-30 11:06:38-0400] INFO - prefect.TaskRunner | Task 'client_df_get_col': Starting task run...
# 30-Jun-22 11:06:38  INFO  115128  task_runner > Task 'client_df_get_col': Starting task run...
# [2022-06-30 11:06:38-0400] INFO - prefect.TaskRunner | Task 'client_df_get_col': Finished task run for task with final state: 'Success'
# 30-Jun-22 11:06:38  INFO  115128  task_runner > Task 'client_df_get_col': Finished task run for task with final state: 'Success'
# [2022-06-30 11:06:38-0400] INFO - prefect.TaskRunner | Task 'client_df_drop': Starting task run...
# 30-Jun-22 11:06:38  INFO  115128  task_runner > Task 'client_df_drop': Starting task run...
# [2022-06-30 11:06:38-0400] INFO - prefect.TaskRunner | Task 'client_df_drop': Finished task run for task with final state: 'Success'
# 30-Jun-22 11:06:38  INFO  115128  task_runner > Task 'client_df_drop': Finished task run for task with final state: 'Success'
# [2022-06-30 11:06:38-0400] INFO - prefect.TaskRunner | Task 'client_fit_transform': Starting task run...
# 30-Jun-22 11:06:38  INFO  115128  task_runner > Task 'client_fit_transform': Starting task run...
# [2022-06-30 11:06:38-0400] INFO - prefect.TaskRunner | Task 'client_fit_transform': Finished task run for task with final state: 'Success'
# 30-Jun-22 11:06:38  INFO  115128  task_runner > Task 'client_fit_transform': Finished task run for task with final state: 'Success'
# [2022-06-30 11:06:38-0400] INFO - prefect.TaskRunner | Task 'client_df_drop': Starting task run...
# 30-Jun-22 11:06:38  INFO  115128  task_runner > Task 'client_df_drop': Starting task run...
# [2022-06-30 11:06:38-0400] INFO - prefect.TaskRunner | Task 'client_df_drop': Finished task run for task with final state: 'Success'
# 30-Jun-22 11:06:38  INFO  115128  task_runner > Task 'client_df_drop': Finished task run for task with final state: 'Success'
# [2022-06-30 11:06:38-0400] INFO - prefect.TaskRunner | Task 'client_df_drop': Starting task run...
# 30-Jun-22 11:06:38  INFO  115128  task_runner > Task 'client_df_drop': Starting task run...
# [2022-06-30 11:06:38-0400] INFO - prefect.TaskRunner | Task 'client_df_drop': Finished task run for task with final state: 'Success'
# 30-Jun-22 11:06:38  INFO  115128  task_runner > Task 'client_df_drop': Finished task run for task with final state: 'Success'
# [2022-06-30 11:06:38-0400] INFO - prefect.TaskRunner | Task 'client_df_drop': Starting task run...
# 30-Jun-22 11:06:38  INFO  115128  task_runner > Task 'client_df_drop': Starting task run...
# [2022-06-30 11:06:38-0400] INFO - prefect.TaskRunner | Task 'client_df_drop': Finished task run for task with final state: 'Success'
# 30-Jun-22 11:06:38  INFO  115128  task_runner > Task 'client_df_drop': Finished task run for task with final state: 'Success'
# [2022-06-30 11:06:38-0400] INFO - prefect.TaskRunner | Task 'client_df_get_col': Starting task run...
# 30-Jun-22 11:06:38  INFO  115128  task_runner > Task 'client_df_get_col': Starting task run...
# [2022-06-30 11:06:38-0400] INFO - prefect.TaskRunner | Task 'client_df_get_col': Finished task run for task with final state: 'Success'
# 30-Jun-22 11:06:38  INFO  115128  task_runner > Task 'client_df_get_col': Finished task run for task with final state: 'Success'
# [2022-06-30 11:06:38-0400] INFO - prefect.TaskRunner | Task 'client_df_drop': Starting task run...
# 30-Jun-22 11:06:38  INFO  115128  task_runner > Task 'client_df_drop': Starting task run...
# [2022-06-30 11:06:38-0400] INFO - prefect.TaskRunner | Task 'client_df_drop': Finished task run for task with final state: 'Success'
# 30-Jun-22 11:06:38  INFO  115128  task_runner > Task 'client_df_drop': Finished task run for task with final state: 'Success'
# [2022-06-30 11:06:38-0400] INFO - prefect.TaskRunner | Task 'client_df_get_col': Starting task run...
# 30-Jun-22 11:06:38  INFO  115128  task_runner > Task 'client_df_get_col': Starting task run...
# [2022-06-30 11:06:38-0400] INFO - prefect.TaskRunner | Task 'client_df_get_col': Finished task run for task with final state: 'Success'
# 30-Jun-22 11:06:38  INFO  115128  task_runner > Task 'client_df_get_col': Finished task run for task with final state: 'Success'
# [2022-06-30 11:06:38-0400] INFO - prefect.TaskRunner | Task 'List': Starting task run...
# 30-Jun-22 11:06:38  INFO  115128  task_runner > Task 'List': Starting task run...
# [2022-06-30 11:06:38-0400] INFO - prefect.TaskRunner | Task 'List': Finished task run for task with final state: 'Success'
# 30-Jun-22 11:06:38  INFO  115128  task_runner > Task 'List': Finished task run for task with final state: 'Success'
# [2022-06-30 11:06:38-0400] INFO - prefect.TaskRunner | Task 'get_result': Starting task run...
# 30-Jun-22 11:06:38  INFO  115128  task_runner > Task 'get_result': Starting task run...
# [2022-06-30 11:06:38-0400] INFO - prefect.TaskRunner | Task 'get_result': Finished task run for task with final state: 'Success'
# 30-Jun-22 11:06:38  INFO  115128  task_runner > Task 'get_result': Finished task run for task with final state: 'Success'
# [2022-06-30 11:06:38-0400] INFO - prefect.TaskRunner | Task 'List': Starting task run...
# 30-Jun-22 11:06:38  INFO  115128  task_runner > Task 'List': Starting task run...
# [2022-06-30 11:06:38-0400] INFO - prefect.TaskRunner | Task 'List': Finished task run for task with final state: 'Success'
# 30-Jun-22 11:06:38  INFO  115128  task_runner > Task 'List': Finished task run for task with final state: 'Success'
# [2022-06-30 11:06:38-0400] INFO - prefect.TaskRunner | Task 'get_result': Starting task run...
# 30-Jun-22 11:06:38  INFO  115128  task_runner > Task 'get_result': Starting task run...
# [2022-06-30 11:06:38-0400] INFO - prefect.TaskRunner | Task 'get_result': Finished task run for task with final state: 'Success'
# 30-Jun-22 11:06:38  INFO  115128  task_runner > Task 'get_result': Finished task run for task with final state: 'Success'
# [2022-06-30 11:06:38-0400] INFO - prefect.FlowRunner | Flow run SUCCESS: all reference tasks succeeded
# 30-Jun-22 11:06:38  INFO  115128  flow_runner > Flow run SUCCESS: all reference tasks succeeded

# %%
print(state.result[resX].result)
print(state.result[resy].result)
# Out:
# [{'id': '0f6eff03b6044f0888ff08f902d23e5e', 'type': "<class 'pandas.core.frame.DataFrame'>", '_SecretClientObject': True}, {'id': '253a0c4f8e6f4c55a45281c7171df31a', 'type': "<class 'pandas.core.frame.DataFrame'>", '_SecretClientObject': True}, {'id': 'ed92886acde44c4e82f5d6b1de409337', 'type': "<class 'pandas.core.frame.DataFrame'>", '_SecretClientObject': True}]
# [{'id': '6da8ef7669d748a7ab137e3c5cf5c6b1', 'type': "<class 'pandas.core.series.Series'>", '_SecretClientObject': True}, {'id': '03e7ffebb856466c92fa5c7b71d84f8c', 'type': "<class 'pandas.core.series.Series'>", '_SecretClientObject': True}, {'id': 'a37239bc7e414cc0874144f3c021d537', 'type': "<class 'pandas.core.series.Series'>", '_SecretClientObject': True}]

# %%
train_state = m.run_graph(state.result[resX].result, state.result[resy].result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-5e327e6b8fba> in <module>
# ----> 1 train_state = m.run_graph(state.result[resX].result, state.result[resy].result)
#
# ~/playground/client_ml.py in run_graph(self, X, y, train_test_ratio, loss_fn, opt_method, epoch, learn_rate)
#     225                 y_trains.append(ytr)
#     226                 y_tests.append(yte)
# --> 227                 model = task_set_model(self.clients[i], shapeX[1], 1)
#     228                 models.append(model)
#     229                 loss_fns.append(task_set_loss_fn(self.clients[i], parameter_loss_fn))
#
# /usr/local/lib/python3.8/dist-packages/prefect/core/task.py in __call__(self, mapped, task_args, upstream_tasks, flow, *args, **kwargs)
#     660         """
#     661         new = self.copy(**(task_args or {}))
# --> 662         new.bind(
#     663             *args, mapped=mapped, upstream_tasks=upstream_tasks, flow=flow, **kwargs
#     664         )
#
# /usr/local/lib/python3.8/dist-packages/prefect/core/task.py in bind(self, mapped, upstream_tasks, flow, *args, **kwargs)
#     701         # this will raise an error if callargs weren't all provided
#     702         signature = inspect.signature(self.run)
# --> 703         callargs = dict(signature.bind(*args, **kwargs).arguments)  # type: Dict
#     704
#     705         # bind() compresses all variable keyword arguments under the ** argument name,
#
# /usr/lib/python3.8/inspect.py in bind(self, *args, **kwargs)
#    3035         if the passed arguments can not be bound.
#    3036         """
# -> 3037         return self._bind(args, kwargs)
#    3038
#    3039     def bind_partial(self, /, *args, **kwargs):
#
# /usr/lib/python3.8/inspect.py in _bind(self, args, kwargs, partial)
#    2956                     param = next(parameters)
#    2957                 except StopIteration:
# -> 2958                     raise TypeError('too many positional arguments') from None
#    2959                 else:
#    2960                     if param.kind in (_VAR_KEYWORD, _KEYWORD_ONLY):
#
# TypeError: too many positional arguments
